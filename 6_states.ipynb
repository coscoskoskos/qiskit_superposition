# %%
import numpy as np
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit import IBMQ, execute, Aer
from qiskit.tools.visualization import plot_histogram
import math

# %%
#3 qubits superposition 8 states
q = QuantumRegister(3, 'q')
c = ClassicalRegister(3, 'c')
qc = QuantumCircuit(q, c)

qc.h(q)

qc.measure(q[0:3], c[0:3])

r = execute(qc, Aer.get_backend('qasm_simulator')).result()
rc = r.get_counts()
print(rc)
plot_histogram(rc)
# Out:
# {'100': 129, '010': 137, '110': 132, '111': 119, '011': 139, '001': 121, '101': 128, '000': 119}

# %% [markdown]
# 1. ry_arc
# 2. operate ch and break down the probability until all states' probability get equal
#
# You also will be able to crete another 5 states superposition by operating x gates or  by changing the control qubit of ch gate.

# %%
def ry_arc(qubit, num):
    theta = 2 * np.arccos(1 / np.power(num, 1 / 4))
    qc.ry(theta, q[qubit])

# %%
prob_sum = 0
iteration = 0

#000, 001, 010, 011, 101, 111
q = QuantumRegister(3, 'q')
c = ClassicalRegister(3, 'c')
qc = QuantumCircuit(q, c)

ry_arc(0, 6)
ry_arc(1, 6)
qc.ch(q[0], q[2])

qc.measure(q[0:3], c[0:3])

r = execute(qc, Aer.get_backend('qasm_simulator')).result()
rc = r.get_counts()
print(rc)
plot_histogram(rc)
# Out:
# {'101': 122, '000': 165, '010': 283, '111': 187, '011': 166, '001': 101}

# %%
#001, 010, 011, 101, 111
q = QuantumRegister(3, 'q')
c = ClassicalRegister(3, 'c')
qc = QuantumCircuit(q, c)

ry_arc(0, 5)
qc.ch(q[0], q[1])
qc.ch(q[0], q[2])
qc.x(q[1])

qc.measure(q[0:3], c[0:3])

r = execute(qc, Aer.get_backend('qasm_simulator')).result()
rc = r.get_counts()
print(rc)
plot_histogram(rc)
# Out:
# {'001': 204, '101': 206, '111': 223, '011': 186, '010': 205}

# %%
#000, 010, 100, 110, 111
q = QuantumRegister(3, 'q')
c = ClassicalRegister(3, 'c')
qc = QuantumCircuit(q, c)

ry_arc(0, 5)
qc.ch(q[0], q[1])
qc.ch(q[0], q[2])
qc.x(q[0:3])

qc.measure(q[0:3], c[0:3])

r = execute(qc, Aer.get_backend('qasm_simulator')).result()
rc = r.get_counts()
print(rc)
plot_histogram(rc)
# Out:
# {'000': 236, '111': 194, '100': 193, '110': 204, '010': 197}

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
